# %%
import pandas as pd

# %%
pollution = pd.read_csv("Resources/Pollution.csv")
population = pd.read_csv("Resources/Population.csv")
pollution
# Out:
#       Unnamed: 0  State Code  County Code  Site Num  \
# 0          63332          36            5        83
# 1          63333          36            5        83
# 2          63334          36            5        83
# 3          63335          36            5        83
# 4          63336          36            5        83
# ...          ...         ...          ...       ...
# 9657       18557           6           37      5001
# 9658       18558           6           37      5001
# 9659       18559           6           37      5001
# 9660       18560           6           37      5001
# 9661       18561           6           37      5001
#
#                                          Address       State       County  \
# 0     200TH STREET AND SOUTHERN BLVD Harding Lab    New York        Bronx
# 1     200TH STREET AND SOUTHERN BLVD Harding Lab    New York        Bronx
# 2     200TH STREET AND SOUTHERN BLVD Harding Lab    New York        Bronx
# ...
