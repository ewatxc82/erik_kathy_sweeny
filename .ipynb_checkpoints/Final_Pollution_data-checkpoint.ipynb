# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# %%
# read pollution csv file
file_path_pollution = ("Resources/pollution_data.csv")


# create the data frame for pollution
pollution_df = pd.read_csv(file_path_pollution)
pollution_df.head()
# Out:
#    Unnamed: 0  State Code  County Code  Site Num                      Address  \
# 0       12130           6           37      1103  1630 N MAIN ST, LOS ANGELES
# 1       12131           6           37      1103  1630 N MAIN ST, LOS ANGELES
# 2       12132           6           37      1103  1630 N MAIN ST, LOS ANGELES
# 3       12133           6           37      1103  1630 N MAIN ST, LOS ANGELES
# 4       12134           6           37      1103  1630 N MAIN ST, LOS ANGELES
#
#         State       County         City Date Local          NO2 Units  ...  \
# 0  California  Los Angeles  Los Angeles   3/1/2000  Parts per billion  ...
# 1  California  Los Angeles  Los Angeles   3/1/2000  Parts per billion  ...
# 2  California  Los Angeles  Los Angeles   3/1/2000  Parts per billion  ...
# 3  California  Los Angeles  Los Angeles   3/1/2000  Parts per billion  ...
# 4  California  Los Angeles  Los Angeles   3/2/2000  Parts per billion  ...
#
# ...

# %%
# select the columns
pollution_df = pollution_df[["State", "City", "Date Local", "NO2 Mean", "NO2 AQI", "O3 Units", "O3 Mean", "O3 AQI", "SO2 Mean", "SO2 AQI", "CO Mean", "CO AQI"]]

# display the new dataframe
pollution_df.head()
# Out:
#         State         City Date Local   NO2 Mean  NO2 AQI           O3 Units  \
# 0  California  Los Angeles   3/1/2000  33.521739       45  Parts per million
# 1  California  Los Angeles   3/1/2000  33.521739       45  Parts per million
# 2  California  Los Angeles   3/1/2000  33.521739       45  Parts per million
# 3  California  Los Angeles   3/1/2000  33.521739       45  Parts per million
# 4  California  Los Angeles   3/2/2000  44.173913       52  Parts per million
#
#     O3 Mean  O3 AQI  SO2 Mean  SO2 AQI   CO Mean  CO AQI
# 0  0.010375      23  0.000000      0.0  1.230435     NaN
# 1  0.010375      23  0.000000      0.0  1.004167    18.0
# 2  0.010375      23  0.000000      NaN  1.230435     NaN
# 3  0.010375      23  0.000000      NaN  1.004167    18.0
# 4  0.009375      21  0.173913      1.0  1.343478     NaN

# %%
pollution_df['Date Local'] = pd.to_datetime(pollution_df['Date Local'], format= '%m/%d/%Y')
pollution_df['Year'] = pollution_df['Date Local'].dt.strftime('%Y')
pollution_df
# Out:
#             State         City Date Local   NO2 Mean  NO2 AQI  \
# 0      California  Los Angeles 2000-03-01  33.521739       45
# 1      California  Los Angeles 2000-03-01  33.521739       45
# 2      California  Los Angeles 2000-03-01  33.521739       45
# 3      California  Los Angeles 2000-03-01  33.521739       45
# 4      California  Los Angeles 2000-03-02  44.173913       52
# ...           ...          ...        ...        ...      ...
# 58067    New York     New York 2010-12-30  51.125000       95
# 58068    New York     New York 2010-12-31  45.375000       51
# 58069    New York     New York 2010-12-31  45.375000       51
# 58070    New York     New York 2010-12-31  45.375000       51
# 58071    New York     New York 2010-12-31  45.375000       51
#
#                 O3 Units   O3 Mean  O3 AQI   SO2 Mean  SO2 AQI   CO Mean  \
# 0      Parts per million  0.010375      23   0.000000      0.0  1.230435
# ...

# %%
# change NaN values to 0
pollution_df.fillna(0, inplace=True)
pollution_df.head()
# Out:
#         State         City Date Local   NO2 Mean  NO2 AQI           O3 Units  \
# 0  California  Los Angeles 2000-03-01  33.521739       45  Parts per million
# 1  California  Los Angeles 2000-03-01  33.521739       45  Parts per million
# 2  California  Los Angeles 2000-03-01  33.521739       45  Parts per million
# 3  California  Los Angeles 2000-03-01  33.521739       45  Parts per million
# 4  California  Los Angeles 2000-03-02  44.173913       52  Parts per million
#
#     O3 Mean  O3 AQI  SO2 Mean  SO2 AQI   CO Mean  CO AQI  Year
# 0  0.010375      23  0.000000      0.0  1.230435     0.0  2000
# 1  0.010375      23  0.000000      0.0  1.004167    18.0  2000
# 2  0.010375      23  0.000000      0.0  1.230435     0.0  2000
# 3  0.010375      23  0.000000      0.0  1.004167    18.0  2000
# 4  0.009375      21  0.173913      1.0  1.343478     0.0  2000

# %%
# Make DataFrame Specific to Los Angeles
LAdf = pollution_df[pollution_df['City'] == 'Los Angeles']
LAdf.reset_index(drop=True, inplace=True)
LAdf
# Out:
#             State         City Date Local   NO2 Mean  NO2 AQI  \
# 0      California  Los Angeles 2000-03-01  33.521739       45
# 1      California  Los Angeles 2000-03-01  33.521739       45
# 2      California  Los Angeles 2000-03-01  33.521739       45
# 3      California  Los Angeles 2000-03-01  33.521739       45
# 4      California  Los Angeles 2000-03-02  44.173913       52
# ...           ...          ...        ...        ...      ...
# 26180  California  Los Angeles 2010-12-30   5.147826       11
# 26181  California  Los Angeles 2010-12-31  19.360870       38
# 26182  California  Los Angeles 2010-12-31  19.360870       38
# 26183  California  Los Angeles 2010-12-31  19.360870       38
# 26184  California  Los Angeles 2010-12-31  19.360870       38
#
#                 O3 Units   O3 Mean  O3 AQI  SO2 Mean  SO2 AQI   CO Mean  \
# 0      Parts per million  0.010375      23  0.000000      0.0  1.230435
# 1      Parts per million  0.010375      23  0.000000      0.0  1.004167
# ...

# %%
# Group DataFrame By Year
LaAnnual = LAdf.groupby('Year')
LaAnnualAvg = LaAnnual.mean()
LaAnnualAvg
# Out:
#        NO2 Mean    NO2 AQI   O3 Mean     O3 AQI  SO2 Mean   SO2 AQI   CO Mean  \
# Year
# 2000  40.105582  60.385621  0.017689  32.722222  1.272629  3.570261  1.066452
# 2001  37.947524  57.236307  0.018871  31.791862  2.453214  3.751174  1.143900
# 2002  32.738006  49.871129  0.021664  33.733267  2.494795  3.323676  1.042911
# 2003  33.625855  51.745665  0.018656  34.182081  2.029541  2.760116  0.959040
# 2004  25.176507  41.478358  0.028144  41.428380  2.617957  3.546185  0.594167
# 2005  20.047939  35.726768  0.023358  33.472954  3.715674  4.059639  0.435051
# 2006  21.986027  37.374121  0.022269  32.140647  1.942946  3.026723  0.383680
# 2007  21.490240  36.435860  0.023823  33.762391  1.801777  2.537172  0.384129
# 2008  20.404282  35.327536  0.023782  34.159420  0.993675  1.726812  0.377043
# 2009  21.817590  34.336698  0.022917  31.991348  1.029771  1.690699  0.520251
# 2010  18.640971  32.194805  0.022634  30.987013  0.466635  0.852092  0.449055
#
#         CO AQI
# Year
# ...

# %%
# Make DataFrame Specific to New York City
NyDf = pollution_df[pollution_df['City'] == 'New York']
NyDf.reset_index(drop=True, inplace=True)
NyDf
# Out:
#           State      City Date Local  NO2 Mean  NO2 AQI           O3 Units  \
# 0      New York  New York 2000-05-05    42.500       57  Parts per million
# 1      New York  New York 2000-05-05    42.500       57  Parts per million
# 2      New York  New York 2000-05-05    42.500       57  Parts per million
# 3      New York  New York 2000-05-05    42.500       57  Parts per million
# 4      New York  New York 2000-05-06    42.875       81  Parts per million
# ...         ...       ...        ...       ...      ...                ...
# 31882  New York  New York 2010-12-30    51.125       95  Parts per million
# 31883  New York  New York 2010-12-31    45.375       51  Parts per million
# 31884  New York  New York 2010-12-31    45.375       51  Parts per million
# 31885  New York  New York 2010-12-31    45.375       51  Parts per million
# 31886  New York  New York 2010-12-31    45.375       51  Parts per million
#
#         O3 Mean  O3 AQI  SO2 Mean  SO2 AQI   CO Mean  CO AQI  Year
# ...

# %%
# Group DataFrame By Year
NyAnnual = NyDf.groupby('Year')
NyAnnualAvg = NyAnnual.mean()
NyAnnualAvg
# Out:
#        NO2 Mean    NO2 AQI   O3 Mean     O3 AQI  SO2 Mean    SO2 AQI  \
# Year
# 2000  26.719275  41.054748  0.017819  27.094098  7.480003  11.256630
# 2001  28.519365  42.667728  0.017997  27.481222  8.559593  12.636856
# 2002  27.652818  41.449814  0.018102  30.296654  7.492871  11.695911
# 2003  26.736325  40.045622  0.017416  25.618102  8.005652  12.080942
# 2004  24.573622  38.027037  0.017233  25.253291  7.095314  11.163999
# 2005  25.711626  39.613861  0.019210  28.948972  7.405940  11.281036
# 2006  24.229218  38.115789  0.019428  27.618947  5.935325   9.854737
# 2007  23.271936  36.919323  0.019392  27.395418  5.566943   8.398904
# 2008  23.104233  37.113665  0.019759  27.486590  5.214913   7.621328
# 2009  21.685017  35.096296  0.019430  25.724444  4.512122   6.786667
# 2010  19.711397  33.435754  0.023306  30.614525  3.856943   5.777235
#
#        CO Mean    CO AQI
# Year
# 2000  0.620531  5.076561
# 2001  0.615518  4.941439
# 2002  0.612747  4.725651
# ...

# %%
# read populatin csv file
file_path_population = "Resources/population_data.csv"

## create the data frame for population
population_df = pd.read_csv(file_path_population, encoding = "ISO-8859-1", low_memory=False)
population_df.head()
# Out:
#    SUMLEV  STATE  COUNTY  PLACE  COUSUB               NAME      STNAME  \
# 0      40      6       0      0       0         California  California
# 1     162      6       0    296       0      Adelanto city  California
# 2     162      6       0    394       0  Agoura Hills city  California
# 3     162      6       0    562       0       Alameda city  California
# 4     162      6       0    674       0        Albany city  California
#
#    ESTIMATESBASE2000  POPESTIMATE2000  POPESTIMATE2001  POPESTIMATE2002  \
# 0           33871653         33987977         34479458         34871843
# 1              18135            18472            20039            21396
# 2              20466            20488            20600            20694
# 3              72258            72524            73332            72785
# 4              16474            16579            16942            16984
#
#    POPESTIMATE2003  POPESTIMATE2004  POPESTIMATE2005  POPESTIMATE2006  \
# ...

# %%
# select the columns
population_df = population_df[["NAME", "STNAME", "POPESTIMATE2000", "POPESTIMATE2001", "POPESTIMATE2002", "POPESTIMATE2003", "POPESTIMATE2004", "POPESTIMATE2005", "POPESTIMATE2006", "POPESTIMATE2007", "POPESTIMATE2008", "POPESTIMATE2009", "POPESTIMATE2010"]]

population_df.head()
# Out:
#                 NAME      STNAME  POPESTIMATE2000  POPESTIMATE2001  \
# 0         California  California         33987977         34479458
# 1      Adelanto city  California            18472            20039
# 2  Agoura Hills city  California            20488            20600
# 3       Alameda city  California            72524            73332
# 4        Albany city  California            16579            16942
#
#    POPESTIMATE2002  POPESTIMATE2003  POPESTIMATE2004  POPESTIMATE2005  \
# 0         34871843         35253159         35574576         35827943
# 1            21396            22921            24565            26138
# 2            20694            20748            20724            20631
# 3            72785            72216            71623            71247
# 4            16984            17021            17049            17124
#
#    POPESTIMATE2006  POPESTIMATE2007  POPESTIMATE2008  POPESTIMATE2009  \
# ...

# %%
LA_city= population_df[population_df['NAME'] == 'Los Angeles city']
LA_city
# Out:
#                  NAME      STNAME  POPESTIMATE2000  POPESTIMATE2001  \
# 239  Los Angeles city  California          3701062          3733328
# 664  Los Angeles city  California          3701062          3733328
#
#      POPESTIMATE2002  POPESTIMATE2003  POPESTIMATE2004  POPESTIMATE2005  \
# 239          3762432          3784279          3792650          3788197
# 664          3762432          3784279          3792650          3788197
#
#      POPESTIMATE2006  POPESTIMATE2007  POPESTIMATE2008  POPESTIMATE2009  \
# 239          3767960          3751872          3763566          3781938
# 664          3767960          3751872          3763566          3781938
#
#      POPESTIMATE2010
# 239          3797162
# 664          3797162

# %%
NYC = population_df[population_df['NAME'] == 'New York city']
NYC
# Out:
#                NAME    STNAME  POPESTIMATE2000  POPESTIMATE2001  \
# 1454  New York city  New York          8017608          8059813
#
#       POPESTIMATE2002  POPESTIMATE2003  POPESTIMATE2004  POPESTIMATE2005  \
# 1454          8072000          8068073          8043366          8013368
#
#       POPESTIMATE2006  POPESTIMATE2007  POPESTIMATE2008  POPESTIMATE2009  \
# 1454          7993906          8013775          8068195          8131574
#
#       POPESTIMATE2010
# 1454          8184899

# %%
# Now transform the rows of desired data into data frames that can be joined with Pollution Data
# Note: This is not the only way to accomplish this goal.
# Alternatively, the headers could have been renamed to simply the name of the years in a string form then the table could be pivoted then merged. 

# Los Angeles Population DataFrame
LA_city_df = pd.DataFrame({"Year": ["2000", "2001", "2002", "2003", "2004", "2005", "2006", "2007", "2008", "2009", "2010"],
                       "Population": [3701062, 3733328, 3762432, 3784279, 3792650, 3788197, 3767960, 3751872, 3763566, 3781938, 3792661]})
LA_city_df.set_index('Year', inplace=True)
LA_city_df
# Out:
#       Population
# Year
# 2000     3701062
# 2001     3733328
# 2002     3762432
# 2003     3784279
# 2004     3792650
# 2005     3788197
# 2006     3767960
# 2007     3751872
# 2008     3763566
# 2009     3781938
# 2010     3792661

# %%
# New York City Population DataFrame to be joined
NY_df = pd.DataFrame({"Year": ["2000", "2001", "2002", "2003", "2004", "2005", "2006", "2007", "2008", "2009", "2010"],
                       "Population": [8017608, 8059813, 8072000, 8068073, 8043366, 8013368, 7993906, 8013775, 8068195, 8131574, 8175133]})
#NyPopDf.set_index('Year', inplace=True)
NY_df.set_index('Year', inplace=True)
NY_df
# Out:
#       Population
# Year
# 2000     8017608
# 2001     8059813
# 2002     8072000
# 2003     8068073
# 2004     8043366
# 2005     8013368
# 2006     7993906
# 2007     8013775
# 2008     8068195
# 2009     8131574
# 2010     8175133

# %%
# Joining these tables 
LAX_df = pd.concat([LaAnnualAvg, LA_city_df], axis=1, join="outer")
LAX_df.head()

# Exporting LA Data Frame to a csv file to be imported into database
LAX_df.to_csv("Resources/LAX_df.csv", index=True, header=True)

# %%
LAX_df.head()
# Out:
#        NO2 Mean    NO2 AQI   O3 Mean     O3 AQI  SO2 Mean   SO2 AQI   CO Mean  \
# Year
# 2000  40.105582  60.385621  0.017689  32.722222  1.272629  3.570261  1.066452
# 2001  37.947524  57.236307  0.018871  31.791862  2.453214  3.751174  1.143900
# 2002  32.738006  49.871129  0.021664  33.733267  2.494795  3.323676  1.042911
# 2003  33.625855  51.745665  0.018656  34.182081  2.029541  2.760116  0.959040
# 2004  25.176507  41.478358  0.028144  41.428380  2.617957  3.546185  0.594167
#
#         CO AQI  Population
# Year
# 2000  9.251634     3701062
# 2001  9.793427     3733328
# 2002  9.088911     3762432
# 2003  8.095376     3784279
# 2004  5.390897     3792650

# %%
#New York DataFrame to be Loaded into database

NYC_df = pd.concat([NyAnnualAvg, NY_df], axis=1, join="outer")
NYC_df

# Exporting NYC Data Frame to a csv file to be imported into database
NYC_df.to_csv("Resources/NYC_df.csv", index=True, header=True)

# %%
NYC_df.head()
# Out:
#        NO2 Mean    NO2 AQI   O3 Mean     O3 AQI  SO2 Mean    SO2 AQI  \
# Year
# 2000  26.719275  41.054748  0.017819  27.094098  7.480003  11.256630
# 2001  28.519365  42.667728  0.017997  27.481222  8.559593  12.636856
# 2002  27.652818  41.449814  0.018102  30.296654  7.492871  11.695911
# 2003  26.736325  40.045622  0.017416  25.618102  8.005652  12.080942
# 2004  24.573622  38.027037  0.017233  25.253291  7.095314  11.163999
#
#        CO Mean    CO AQI  Population
# Year
# 2000  0.620531  5.076561     8017608
# 2001  0.615518  4.941439     8059813
# 2002  0.612747  4.725651     8072000
# 2003  0.697558  5.245033     8068073
# 2004  0.579264  4.307364     8043366

# %%
engine = create_engine('postgresql://postgres:postgres@localhost:5433/city_population_pollution')
connection = engine.connect()

# %%
# Confirm tables
engine.table_names()
# Out:
# ['lax_df', 'nyc_df']
